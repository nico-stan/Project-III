# %%
# Importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import socket
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import bs4 as bs
import src.cleaning as src

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
urls = ['https://www.numbeo.com/cost-of-living/compare_cities.jsp?country1=United+States&country2=United+Kingdom&city1=San+Francisco%2C+CA&city2=London',
        'https://www.numbeo.com/cost-of-living/compare_cities.jsp?country1=United+States&country2=United+States&city1=New+York%2C+NY&city2=San+Francisco%2C+CA']

# %%
res = requests.get('https://www.numbeo.com/cost-of-living/compare_cities.jsp?country1=United+States&country2=United+Kingdom&city1=San+Francisco%2C+CA&city2=London')
html = res.content
soup = bs.BeautifulSoup(html, "html.parser")
df_SF_LO = pd.read_html(html)[2]
df_SF_LO
# Out:
#                                           Restaurants  San Francisco, CA Edit  \
# 0                        Meal, Inexpensive Restaurant        20.00 $(16.43 £)
# 1   Meal for 2 People, Mid-range Restaurant, Three...       100.00 $(82.14 £)
# 2      McMeal at McDonalds (or Equivalent Combo Meal)         11.00 $(9.03 £)
# 3                   Domestic Beer (0.5 liter draught)          7.00 $(5.75 £)
# 4                   Imported Beer (0.33 liter bottle)          8.00 $(6.57 £)
# ..                                                ...                     ...
# 61                             Salaries And Financing  San Francisco, CA Edit
# 62             Average Monthly Net Salary (After Tax)  8,137.67 $(6,683.91 £)
# 63  Mortgage Interest Rate in Percentages (%), Yea...                    5.24
# 64                                       Last update:               July 2022
# 65                Contributors in the past 12 months:                     274
#
# ...

# %%
res = requests.get('https://www.numbeo.com/cost-of-living/compare_cities.jsp?country1=United+States&country2=United+States&city1=New+York%2C+NY&city2=San+Francisco%2C+CA')
html = res.content
soup = bs.BeautifulSoup(html, "html.parser")
df_SF_NY = pd.read_html(html)[2]
df_SF_NY
# Out:
#                                           Restaurants  New York, NY Edit  \
# 0                        Meal, Inexpensive Restaurant            25.00 $
# 1   Meal for 2 People, Mid-range Restaurant, Three...           100.00 $
# 2      McMeal at McDonalds (or Equivalent Combo Meal)            10.00 $
# 3                   Domestic Beer (0.5 liter draught)             8.00 $
# 4                   Imported Beer (0.33 liter bottle)            10.00 $
# ..                                                ...                ...
# 61                             Salaries And Financing  New York, NY Edit
# 62             Average Monthly Net Salary (After Tax)         6,515.79 $
# 63  Mortgage Interest Rate in Percentages (%), Yea...               5.21
# 64                                       Last update:          July 2022
# 65                Contributors in the past 12 months:                531
#
#     San Francisco, CA Edit Difference
# 0                  20.00 $   -20.00 %
# ...

# %%
res = requests.get('https://www.numbeo.com/cost-of-living/compare_cities.jsp?country1=United+States&country2=United+States&city1=New+York%2C+NY&city2=San+Francisco%2C+CA')
html = res.content
soup = bs.BeautifulSoup(html, "html.parser")
df_SF_NY = pd.read_html(html)[2]
df_SF_NY
# Out:
#                                           Restaurants  New York, NY Edit  \
# 0                        Meal, Inexpensive Restaurant            25.00 $
# 1   Meal for 2 People, Mid-range Restaurant, Three...           100.00 $
# 2      McMeal at McDonalds (or Equivalent Combo Meal)            10.00 $
# 3                   Domestic Beer (0.5 liter draught)             8.00 $
# 4                   Imported Beer (0.33 liter bottle)            10.00 $
# ..                                                ...                ...
# 61                             Salaries And Financing  New York, NY Edit
# 62             Average Monthly Net Salary (After Tax)         6,515.79 $
# 63  Mortgage Interest Rate in Percentages (%), Yea...               5.21
# 64                                       Last update:          July 2022
# 65                Contributors in the past 12 months:                531
#
#     San Francisco, CA Edit Difference
# 0                  20.00 $   -20.00 %
# ...

# %%
dataframe_1 = pd.merge(df_SF_NY, df_SF_LO, how = "inner", on = ["Restaurants", "Restaurants"])

# %%
dataframe_1
# Out:
#                                           Restaurants  New York, NY Edit  \
# 0                        Meal, Inexpensive Restaurant            25.00 $
# 1   Meal for 2 People, Mid-range Restaurant, Three...           100.00 $
# 2      McMeal at McDonalds (or Equivalent Combo Meal)            10.00 $
# 3                   Domestic Beer (0.5 liter draught)             8.00 $
# 4                   Imported Beer (0.33 liter bottle)            10.00 $
# ..                                                ...                ...
# 63                             Salaries And Financing  New York, NY Edit
# 64             Average Monthly Net Salary (After Tax)         6,515.79 $
# 65  Mortgage Interest Rate in Percentages (%), Yea...               5.21
# 66                                       Last update:          July 2022
# 67                Contributors in the past 12 months:                531
#
#    San Francisco, CA Edit_x Difference_x San Francisco, CA Edit_y  \
# ...
